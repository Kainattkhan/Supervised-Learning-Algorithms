# %%
#importing all libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#EXPLORING DATA
#for returning null values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data["Outcome"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
plt.boxplot(data=data, x=data["Pregnancies"])
plt.show()

# %% [markdown]
# boxplot explanation: above
# orange point = median
# first quartile = 1.5
# 2nd quartile = median to end of the box
# 3rd quartile = median to 12.5
# 4th quartile = otside it

# %%
plt.boxplot(data=data, x=data["Age"])
plt.show()

# %%
plt.pie(data.Outcome.value_counts(), labels = ["Diabetes", "Not Diabetes"],autopct = '%.f')
plt.title("Outcome proportionality")
plt.show()

# %%
#preparin gdata
x= data[[ "Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age"]]
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y= data["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#splitting data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.25, random_state = 5)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2       84              0              0        0   0.0
# 618            9      112             82             24        0  28.2
# 346            1      139             46             19       83  28.7
# 294            0      161             50              0        0  21.9
# 231            6      134             80             37      370  46.2
# ..           ...      ...            ...            ...      ...   ...
# 71             5      139             64             35      140  28.6
# 106            1       96            122              0        0  22.4
# 270           10      101             86             37        0  45.6
# 435            0      141              0              0        0  42.4
# 102            0      125             96              0        0  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 567            6       92             62             32      126  32.0
# 123            5      132             80              0        0  26.8
# 615            3      106             72              0        0  25.8
# 492            4       99             68             38        0  32.8
# 288            4       96             56             17       49  20.8
# ..           ...      ...            ...            ...      ...   ...
# 228            4      197             70             39      744  36.7
# 702            1      168             88             29        0  35.0
# 479            4      132             86             31        0  28.0
# 212            7      179             95             31        0  34.2
# 660           10      162             84              0        0  27.7
#
#      DiabetesPedigreeFunction  Age
# 567                     0.085   46
# 123                     0.186   69
# ...

# %%
y_train
# Out:
# 582    0
# 475    0
# 600    0
# 647    1
# 149    0
#       ..
# 73     0
# 400    1
# 118    0
# 701    1
# 206    1
# Name: Outcome, Length: 576, dtype: int64

# %%
y_test
# Out:
# 567    0
# 123    0
# 615    0
# 492    0
# 288    0
#       ..
# 228    0
# 702    1
# 479    0
# 212    0
# 660    0
# Name: Outcome, Length: 192, dtype: int64

# %%
#MODEL TRAINING
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter = 1000)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.coef_
# Out:
# array([[ 1.36527886e-01,  3.58570138e-02, -1.65038374e-02,
#         -4.17992209e-03, -4.41441690e-04,  8.74652138e-02,
#          1.15408079e+00,  2.37011464e-02]])

# %%
predictions = model.predict(x_test)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cof_matrix = confusion_matrix(y_test, predictions)
plt.figure(dpi = 100)
sns.heatmap(cof_matrix, annot = True, fmt ="d", cmap = "Blues")
plt.plot(x_test)
plt.show()

# %%
Result = pd.DataFrame({"Actual": y_test, "Predictions": predictions})
Result
# Out:
#      Actual  Predictions
# 567       0            0
# 123       0            0
# 615       0            0
# 492       0            0
# 288       0            0
# ..      ...          ...
# 228       0            1
# 702       1            1
# 479       0            0
# 212       0            1
# 660       0            1
#
# [192 rows x 2 columns]
